# %%
import pandas as pd

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Resources/yearlyUCR.csv"
ucr_data = pd.read_csv(csv_file)
ucr_data
# Out:
#     state  year  inc_num
# 0      AK  2011    23510
# 1      AK  2012    24449
# 2      AK  2013    25920
# 3      AK  2014    25018
# 4      AK  2015    26197
# 5      AK  2016    30842
# 6      AL  2011   193358
# 7      AL  2012   190571
# 8      AL  2013   182669
# 9      AL  2014   174814
# 10     AL  2015   167742
# 11     AL  2016   169137
# 12     AR  2011   124603
# 13     AR  2012   123240
# 14     AR  2013   120182
# 15     AR  2014   113700
# 16     AR  2015   113160
# 17     AR  2016   114655
# 18     AZ  2011   256685
# 19     AZ  2012   259778
# 20     AZ  2013   250870
# 21     AZ  2014   239828
# 22     AZ  2015   235152
# 23     AZ  2016   239859
# 24     CA  2011  1128765
# 25     CA  2012  1210409
# 26     CA  2013  1173646
# 27     CA  2014  1100956
# 28     CA  2015  1191797
# 29     CA  2016  1176866
# ..    ...   ...      ...
# 276    VT  2011    16011
# 277    VT  2012    16544
# 278    VT  2013    14657
# 279    VT  2014    10364
# 280    VT  2015     9811
# ...
